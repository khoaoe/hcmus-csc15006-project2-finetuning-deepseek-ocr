# %% [markdown]
# # 📘 Result Analysis & Visualization

# %% [markdown]
# ## 1. Load Outputs

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from IPython.display import display, HTML

# Cấu hình hiển thị
pd.set_option('display.max_colwidth', None)
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Đọc dữ liệu (Thay đổi đường dẫn file nếu cần)
df_baseline = pd.read_csv('/content/deepseek_ocr_baseline_results.csv')
df_finetune = pd.read_csv('/content/evaluation_results.csv')

# Đổi tên cột để phân biệt khi gộp
df_baseline = df_baseline.rename(columns={'prediction': 'pred_baseline', 'cer': 'cer_baseline'})
df_finetune = df_finetune.rename(columns={'prediction': 'pred_finetune', 'cer': 'cer_finetune'})

# Gộp 2 dataframe dựa trên tên ảnh và ground truth
# Giả sử cột 'image' là định danh duy nhất
df_merged = pd.merge(
    df_baseline[['image', 'ground_truth', 'pred_baseline', 'cer_baseline']],
    df_finetune[['image', 'pred_finetune', 'cer_finetune']],
    on='image',
    how='inner'
)

# Tính mức độ cải thiện (CER giảm là tốt -> improvement dương)
df_merged['cer_improvement'] = df_merged['cer_baseline'] - df_merged['cer_finetune']

print(f"Số lượng mẫu đánh giá: {len(df_merged)}")
df_merged.head(5)
# Out:
# Số lượng mẫu đánh giá: 201
#                                                                     image  \
# 0  /kaggle/input/uit-hwdb/UIT_HWDB_line/UIT_HWDB_line/test_data/253/1.jpg
# 1  /kaggle/input/uit-hwdb/UIT_HWDB_line/UIT_HWDB_line/test_data/253/2.jpg
# 2  /kaggle/input/uit-hwdb/UIT_HWDB_line/UIT_HWDB_line/test_data/253/3.jpg
# 3  /kaggle/input/uit-hwdb/UIT_HWDB_line/UIT_HWDB_line/test_data/253/4.jpg
# 4  /kaggle/input/uit-hwdb/UIT_HWDB_line/UIT_HWDB_line/test_data/253/5.jpg
#
#                                                                      ground_truth  \
# 0    Viết tiếp về vụ anh Trương Xuân Đại. Ngay từ khi tờ báo có bài " Số phận của
# 1    những người nói lên sự thật " phát hành, nhiều bạn đọc đã bày tỏ sự chia sẻ,
# 2  ủng hộ anh Trương Xuân Đại. Một bạn đọc 67 tuổi ở Q.11 đến gửi tặng anh Trương
# 3      Xuân Đại 150.000 đồng, một cô gái tên Nhung ở Tân Bình gửi tặng 100.000 đ,
# 4                      một thanh niên tên Hà đến gửi 200.000 đ. Sau đó nữa là rất
#
#                                                                              pred_baseline  \
# 0              Vui tôi tiếp vẫn muốn tham gia Xuân Đại. Ngày tôi thôi tự bảo "cô phẩm của"
# 1  making no doubt lei is that that's what's in, there's been a lot of big to us this set.
# 2           ng họ anh Trường Xuân Đại. Mặt bàn đác 6 tầng là 8 Q. Miền gửi tặng anh Trường
# 3          yīcuān Dùn 150.000 zhāng, mǎi cǎo gēn lǐn Nìngyù? Tūn Bǐnzhū gōng fēng 100.000,
# 4                                    mẹ thành mẹ nữ Hai đến quý 200.000. Sand và mẹ là mẹ!
#
#    cer_baseline  \
# 0      0.486842
# 1      0.723684
# 2      0.256410
# 3      0.459459
# 4      0.465517
#
#                                                                      pred_finetune  \
# 0         Việc tiếp về vụ anh Trương Xuân Đại. Ngày từ khi tổ báo " cơ sở phân của
# 1     những người nói lên sự thật " phát hành, nhân lâm đặc sắc bằng tố cáo của sự
# 2  ứng hộ anh Trương Xuân Đại. Mặt bọn đạc 67 tuổi ở Q. 11 đến gửi tặng anh Trương
# 3         Xuân Đại 150.000 đồng, một cô gái tên Nhung ở Tân Bình qui tụng 100.000,
# 4                        mặt thanh niên tên Hà đến quý 200.000. Sau đó mùa là này,
#
#    cer_finetune  cer_improvement
# 0      0.171053         0.315789
# 1      0.276316         0.447368
# 2      0.064103         0.192308
# 3      0.067568         0.391892
# 4      0.206897         0.258621

# %% [markdown]
# ## 2. Quantitative Analysis

# %%
# Tính toán các chỉ số trung bình
avg_cer_baseline = df_merged['cer_baseline'].mean()
avg_cer_finetune = df_merged['cer_finetune'].mean()
cer_reduction = avg_cer_baseline - avg_cer_finetune
percent_improvement = (cer_reduction / avg_cer_baseline) * 100

# Tạo DataFrame tổng hợp
summary_df = pd.DataFrame({
    'Metric': ['Average CER', 'Median CER', 'Max CER', 'Std Dev'],
    'Baseline Model': [
        df_merged['cer_baseline'].mean(),
        df_merged['cer_baseline'].median(),
        df_merged['cer_baseline'].max(),
        df_merged['cer_baseline'].std()
    ],
    'Fine-tuned Model': [
        df_merged['cer_finetune'].mean(),
        df_merged['cer_finetune'].median(),
        df_merged['cer_finetune'].max(),
        df_merged['cer_finetune'].std()
    ]
})

# Format hiển thị
print(f"=== KẾT QUẢ TỔNG HỢP ===")
print(f"Baseline Average CER: {avg_cer_baseline:.4f}")
print(f"Fine-tuned Average CER: {avg_cer_finetune:.4f}")
print(f"Mức độ cải thiện (Absolute Reduction): {cer_reduction:.4f}")
print(f"Tỷ lệ cải thiện (Relative Improvement): {percent_improvement:.2f}%")
display(summary_df)
# Out:
# === KẾT QUẢ TỔNG HỢP ===
# Baseline Average CER: 1.0569
# Fine-tuned Average CER: 0.1157
# Mức độ cải thiện (Absolute Reduction): 0.9411
# Tỷ lệ cải thiện (Relative Improvement): 89.05%
#         Metric  Baseline Model  Fine-tuned Model
# 0  Average CER        1.056886          0.115737
# 1   Median CER        0.318182          0.058824
# 2      Max CER      130.948052          0.584615
# 3      Std Dev        9.211238          0.141732

# %% [markdown]
# ### 3. Visual Analysis

# %%
# --- BƯỚC 1: XỬ LÝ & THỐNG KÊ OUTLIER ---
# Định nghĩa ngưỡng Outlier (Thường CER > 1.0 hoặc 1.5 là rất tệ)
outlier_threshold = 1.5

# Đếm số lượng outlier
outliers_base = df_merged[df_merged['cer_baseline'] > outlier_threshold]
outliers_ft = df_merged[df_merged['cer_finetune'] > outlier_threshold]

print(f"=== THỐNG KÊ OUTLIER (CER > {outlier_threshold}) ===")
print(f"Số mẫu Baseline bị outlier: {len(outliers_base)} trên tổng số {len(df_merged)} ({len(outliers_base)/len(df_merged):.2%})")
print(f"Số mẫu Fine-tuned bị outlier: {len(outliers_ft)} trên tổng số {len(df_merged)} ({len(outliers_ft)/len(df_merged):.2%})")

# Tạo dataframe sạch chỉ dùng để vẽ biểu đồ (loại bỏ các ca quá tệ để biểu đồ đẹp hơn)
# Lưu ý: Khi tính toán số liệu trung bình ở Cell 2 vẫn nên dùng df gốc để trung thực,
# nhưng khi vẽ biểu đồ phân phối thì cắt bớt đuôi để dễ nhìn.
df_plot = df_merged[
    (df_merged['cer_baseline'] <= outlier_threshold) &
    (df_merged['cer_finetune'] <= outlier_threshold)
].copy()

print(f"\nĐang vẽ biểu đồ trên {len(df_plot)} mẫu dữ liệu (đã lọc outlier)...")

# --- BƯỚC 2: VẼ BIỂU ĐỒ ---
fig, axes = plt.subplots(1, 2, figsize=(20, 7))

# Biểu đồ 1: Histogram (Phân phối lỗi)
# Sử dụng binwidth cố định để dễ so sánh
sns.histplot(data=df_plot, x='cer_baseline', color='#e74c3c', alpha=0.5, label='Baseline', kde=True, ax=axes[0], binwidth=0.05)
sns.histplot(data=df_plot, x='cer_finetune', color='#2ecc71', alpha=0.5, label='Fine-tuned', kde=True, ax=axes[0], binwidth=0.05)

axes[0].set_title(f'Phân phối CER', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Character Error Rate (0.0 = Hoàn hảo)')
axes[0].set_ylabel('Số lượng mẫu')
axes[0].set_xlim(0, outlier_threshold) # Giới hạn trục X
axes[0].legend()

# Biểu đồ 2: Scatter Plot (So sánh đối đầu)
sns.scatterplot(x='cer_baseline', y='cer_finetune', data=df_plot, alpha=0.6, color='#3498db', s=60, ax=axes[1])

# Vẽ đường chéo tham chiếu
# Điểm nằm DƯỚI đường này -> Fine-tune tốt hơn Baseline
# Điểm nằm TRÊN đường này -> Fine-tune tệ hơn
axes[1].plot([0, outlier_threshold], [0, outlier_threshold], 'r--', linewidth=2, label='Không thay đổi (y=x)')

# Tô màu vùng cải thiện (Tam giác dưới)
x_vals = np.linspace(0, outlier_threshold, 100)
axes[1].fill_between(x_vals, 0, x_vals, color='green', alpha=0.1, label='Vùng cải thiện (Better)')
axes[1].fill_between(x_vals, x_vals, outlier_threshold, color='red', alpha=0.05, label='Vùng tệ đi (Worse)')

axes[1].set_title('So sánh đối đầu: Baseline vs Fine-tuned', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Baseline CER')
axes[1].set_ylabel('Fine-tuned CER')
axes[1].set_xlim(0, outlier_threshold)
axes[1].set_ylim(0, outlier_threshold)
axes[1].legend()

plt.tight_layout()
plt.show()

# --- BƯỚC 3: BOXPLOT SO SÁNH (Thêm cái này để nhìn rõ trung vị) ---
plt.figure(figsize=(10, 6))
plot_data = pd.melt(df_plot[['cer_baseline', 'cer_finetune']].rename(columns={
    'cer_baseline': 'Baseline Model',
    'cer_finetune': 'Fine-tuned Model'
}))

sns.boxplot(data=plot_data, x='variable', y='value', palette=['#e74c3c', '#2ecc71'], width=0.5, hue='variable', legend=False)
plt.title('So sánh phân bố lỗi', fontsize=14)
plt.xlabel('Mô hình')
plt.ylabel('CER')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# === THỐNG KÊ OUTLIER (CER > 1.5) ===
# Số mẫu Baseline bị outlier: 1 trên tổng số 201 (0.50%)
# Số mẫu Fine-tuned bị outlier: 0 trên tổng số 201 (0.00%)
#
# Đang vẽ biểu đồ trên 200 mẫu dữ liệu (đã lọc outlier)...

# %% [markdown]
# ### 4. Error Patterns

# %%
def highlight_diff(row):
    """Hàm tô màu cho dataframe hiển thị"""
    color = '#d1e7dd' if row['cer_improvement'] > 0 else '#f8d7da'
    return [f'background-color: {color}' for _ in row]

# 1. Top những mẫu cải thiện nhiều nhất (Success Cases) (giá trị tuyệt đối)
top_improvements = df_merged.nlargest(5, 'cer_improvement')abs

print("=== TOP 5 TRƯỜNG HỢP CẢI THIỆN NHIỀU NHẤT (SUCCESS CASES) ===")
display(top_improvements[['ground_truth', 'pred_baseline', 'pred_finetune', 'cer_baseline', 'cer_finetune']])
# Out:
# === TOP 5 TRƯỜNG HỢP CẢI THIỆN NHIỀU NHẤT (SUCCESS CASES) ===
#                                                                       ground_truth  \
# 23   các nhà đầu tư trong Khu chế xuất Tân Thuận. Vậy thì khi không khắc phục ngay
# 88                                                                    330.000 km2)
# 67                                                                            đất.
# 148                                                                            ngờ
# 57            ta thực hiện hai cơ chế (vừa Nhà nước thực hiện thu hồi đất như cách
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 23   салчын дүнүн кур болгон дүн сүнүн "Тонн Чынын" үнүн чынын дүнүн "Тонн Чынын" үнүн чынум дүнүн "Тонн Чынын" үнүн чындын дүнүн "Тонн Чынын" үнүн дүнүн "Тонн Чынын" үнүн "Тонн Чынын" үнүн "Тоннын" үнүн "Тоннын" үнүн "Тонын" үнүн "Тонын" үнүн "Тоннын" үнүн "Тонын" үнүн "Тоннын" үнүн "Тоның" үнүн "Тоннын" үнүн "Тоңнын" үнүн "Тоңнын" үнүн "тоңнын" үнүн "Тоңнын" үнүн үнүн "Тоңнын" үнүн үнүн үнүн "Тоңнын" үнүн "Тоңын" үнүн "Тоңын" үнүн үнүн үнүн үнүн үнүн үнүрүн үнүн үнүн үнүн үнүн үүнүн үнүн үнүн үнүн үнүн "Тоңнын"үнүн үнүн үнүн үнүн үнүр үнүн үнүн үнүн үнүн үнүүн үнүн үнүн үнүн үнүн үңүн үнүн үнүн үнүн үнүн үчүн үнүн үнүн үнүн үнүн үрүн үнүн үнүн үнүн үнүн "тоңнын"үнүн үнүн үнүн үнүрүн үн үнүн үнүн үнүн үнүн үн үнүн үнүн үнүн үнүрүнүн үнүн үнүн үнүн үнүүрүнүн үнүн үнүн үнүн үүнүрүнүн үнүн үнүн үнүнүн үнүн үнүн үнүн үнүңүнүн үнүн үнүн үнүн үнүкүнүн үнүн үнүн үнүн үнүсүнүн үнүн үнүн үнүн үнүтүн үнүн үнүн үнүн үнүн үтүн үнүн үнүн үнүн үнүнүн үн үнүн үнүн үнүн үн үнүнүн үнүн үнүн үнүнүн үүнүн үнүн үнүн үнүрүнүнүн үнүн үнүн үнүн үн үн үнүн үнүн үнүн үнүнүнүн үнүн үнүн үнүн үүн үнүн үнүн үнүн үнүн үөнүн үнүн үнүн үнүн үнүнүрүнүн үнүн үнүн үнүрүнүрүнүн үнүн үнүн үнүкүнүнүн үнүн үнүн үнүн үчүнүн үнүн үнүн үнүн үнүдүн үнүн үнүн үнүн үнүн үндүн үнүн үнүн үнүн үнүн үдүн үнүн үнүн үнүн үнүнүдүн үнүн үнүн үнүн үн үнүдүн үнүн үнүн үнүнүн үнүдүн үнүн үнүн үн үнүдүн үчүн үнүн үнүн үнүн үндүн үчүн үнүн үнүн үнүн үчүн үчүн үнүн үнүн үнүн үүнүнүн үнүн үнүн үүнүн үнүрүнүн үнүн үнүнүн үүнүн үүнүн үнүн үүнүн үүнүн үүнүн үүнүн үнүн үнүн үүнүн үүнүн үүрүнүн үнүн үүнүн үүнүн үөнүн үүнүн үүнүн үүнүн үөнүн үөнүн үүнүн үүнүн үөнүн ү үнүн үүнүн үүнүн үүнүнүн үүнүн үүнүн үүнүнүрүнүн үүнүн үүнүн үүнүн Үүнүн үүнүн үүнүн үүнүн өнүн үүнүн үүнүн үүнүн ү үнүн үүнүн үүнүн ү үнүн ү үнүн үүнүн үүнүн ү өнүн үүнүн үүнүн ү үнүн ү өнүн үүнүн ү үнүн ү үнүн ү үнүн ү үнүн үүнүн ү үнүн ү үнүн ү өнүн ү үнүн ү үнүн ү үнүн ү өнүн үүнүн үүнүн үүнүн ұнүн ү үнүн ү үнүн ү үнүн ү ұнүн ү үнүн ү үнүн ү үнүрүнүн ү үнүн ү үнүн ү үнүнүн ү үнүн ү үнүн ү үнүн ұнүн ү үнүн ү үнүн ү ұнүнүн ү үнүн ү үнүн ү үнүрүүнүн ү үнүн ү үнүн ү үнүн өнүн ү үнүн ү үнүн ү үнүнүрүнүн ү үнүн ү үнүн ү үүнүн ү үнүн ү үнүн ү үнүр үнүн ү үнүн ү үнүн ү үнүнүүнүн ү үнүн ү үнүн ү үнүр өнүн ү үнүн ү үнүн ү үнүн өүнүн ү үнүн ү үнүн ү үнүнөнүн ү үнүн ү үнүн өнүн ү үүнүн ү үнүн өнүн ү үнүн өнүн ү үнүн өн үүнүн ү үнүн өнүн ү үнүн ү үүнүн өнүн ү үнүн өнүн ү үн үнүн өнүн ү үнүн өнүн ү үүнүн өнүн ү үнүн өүнүн ү үнүн өнүн ү үнүн өүнүн ү үүнүн өнүн ү үнүн өөнүн ү үнүн өөнүн ү үнүн өнүн ү үнүн өөнүн ү үүнүн өөнүн ү үнүн өөнүн үүнүн өөнүн ү үнүн өөнүүнүн ү үнүн өөнүн ү үнүн ө өнүн ү үнүн өөнүн ү үнүн ү үнүн өөнүн ү үнүн өүнүн ү үнүн өөнүн ү үнүн ү өөнүн ү үнүн өөнүн ү үнүрүнүн ү үнүн өөнүн ү үнүн ұнүн ү үнүн өөнүн ү үнүн ҳнүн ү үнүн өөнүн ү үнүн ҷнүн ү үнүн өөнүн ү үнүн ҵнүн ү үнүн өөнүн ү үнүн Ҷнүн ү үнүн өөнүн ү үнүн ҹнүн ү үнүн өөнүн ү үнүн Һнүн ү үнүн өөнүн ү үнүн һнүн ү үнүн өөнүн ү үнүн Ҹнүн ү үнүн өөнүн ү үнүн Ҽнүн ү үнүн өөнүн ү үнүн ҽнүн ү үнүн өөнүн ү үнүн ҿнүн ү үнүн өөнүн ү үнүн өӨнүн ү үнүн өөнүн ү үнүн өҹнүн ү үнүн өөнүн ү үнүн өһнүн ү үнүн өөнүн ү үнүн өңүнүн ү үнүн өһнүн ү үнүн өһнүн ү үнүн өңүнүн ү үнүн ү өһнүн ү үнүн өңүнүн ү үн үнүн өңүнүн ү үнүн өңүнүн ү үнүн ҷнүн ү үнүн өңүнүн ү үнүнүн өңүнүн ү үнүн ү өңүнүн ү үнүн ү өңүнүн үүнүн ү өңүнүн ү үнүн ү өңүүнүн ү үнүн ү өңүүнүн ү үүнүн ү өңүүнүн ү үнүн ү өңуүнүн ү үнүн ү өңүүнүн ү үндүн ү үнүн ү өңүүнүн ү үнүрүнүн ү үнүн ү өңүүнүн ү үдүн ү үнүн ү өңүүнүн ү үнүүн ү өңүүнүн ү үнүн ү өңүнүн ү үн үнүн ү өңүүнүн ү үнүн ү өнүн ү үнүн ү өңүүнүн ү үн үнүн ү өңүүнүнүн ү үнүн ү өңүүнүн ү үңүнүн ү өңүүнүн ү үнүн ү өн үнүн ү өңүүнүн ү үнүн ү үнүн ү өңүүнүн ү үн ҷнүн ү үнүн ү өңүүнүн ү үн өңүүнүн ү үнүн ү өңүүнүүн ү үнүн ү өңүүнүн ү үнүдүн ү үнүн ү өңүүнүн ү үн үүнүн ү өңүүнүн ү үнүн ү үн үнүн ү өңүүнүн үүнүн ү өңүүнүн ү үнүнүн ү өңүүнүн ү үнүн ү өүнүн ү үнүн ү өңүүнүн ү үінүн ү өңүүнүн ү үнүн ү өңүуүнүн ү үнүн ү өңүүнүн үүнүн ү өүнүн ү үнүн ү өңүүүнүн ү үнүн ү өңүүнүн үүүнүн ...
# 88                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 67                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 148                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
#
#                                                                         pred_finetune  \
# 23   các anh ơi đùm lưu trong khi xin tôi tham gia. Vậy thì không khỏi việc phục ngày
# 88                                                                        300.000 km2
# 67                                                                               đất.
# 148                                                                               ngờ
# 57             ra thuộc hiệu hai cơ chế (vừa Nhà nước thuộc hiệu thu hồi đất như cách
#
#      cer_baseline  cer_finetune
# 23     130.948052      0.441558
# 88       1.416667      0.166667
# 67       1.000000      0.000000
# 148      1.000000      0.000000
# 57       1.029412      0.102941

# %%
# 2. Những mẫu mô hình Fine-tuned làm tệ hơn (Failure Cases)
# Đây là phần quan trọng cho mục "Discussion" -> "Limitations"
top_regressions = df_merged.nsmallest(5, 'cer_improvement')

print("\n=== TOP 5 TRƯỜNG HỢP SUY GIẢM CHẤT LƯỢNG (FAILURE CASES) ===")
display(top_regressions[['ground_truth', 'pred_baseline', 'pred_finetune', 'cer_baseline', 'cer_finetune']])
# Out:
# === TOP 5 TRƯỜNG HỢP SUY GIẢM CHẤT LƯỢNG (FAILURE CASES) ===
#                                                                  ground_truth  \
# 183         nhanh chóng khắc phục tình trạng quan liêu, cửa quyền, hách dịch.
# 193          Triển khai quyết định của TP về một số chính sách ưu đãi đối với
# 142                                                   BẢN CHẤT CỦA THÀNH CÔNG
# 7    đã tố cáo tiêu cực ở đường liên cảng A5 10 triệu đồng. Đừng để người dân
# 125          tham nhũng, lãng phí, làm thất thoát tài sản nhà nước... Về kinh
#
#                                                             pred_baseline  \
# 183     nhans chóng thúc phục tình trạng quan liêu, của quyển, hạch dịch.
# 193       Trình khai quyết định của TP về mở sổ chính sách dự án đối với.
# 142                                               Bản chất của thành công
# 7    để tôi có thân cuộc ở đây, bạn cộng A5 10 năm đây. Đây, để người bạn
# 125      tham nhung, làng phí, làm thật thoát tài sản nhà nước... Viêm nh
#
#                                                              pred_finetune  \
# 183       nhân chóng thác phục tình trạng quan liêu của quyền, khách dành.
# 193       Triển khai quyết định của TP về môi đô chất sạch du lịch đối với
# 142                                                BẢN CHẤT CỦA THÀNH CÔNG
# 7    để tổ chức cuộc ở đường lưu cộng A5 10 tuần đông. Đảng, các nguồn vốn
# 125        tham nhũng, lặng phí, làm chất thốt tại sân nhà nước... Về kinh
#
#      cer_baseline  cer_finetune
# 183      0.092308      0.138462
# 193      0.187500      0.203125
# 142      0.000000      0.000000
# 7        0.430556      0.416667
# 125      0.109375      0.093750
